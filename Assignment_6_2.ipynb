# %% [markdown]
# <a href="https://colab.research.google.com/github/coolksrini/edureka_python_course/blob/main/Assignment_6_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1. You are given a dataset, which is present in the LMS, containing the number of hurricanes occurring in the United States along the coast of the Atlantic. Load the data from the dataset into your program and plot a Bar Graph of the data, taking the Year as the x-axis and the number of hurricanes occurring as the Y-axis.

# %%
import pandas as pd
import matplotlib.pyplot as plt

hurricanes_df = pd.read_csv("/content/sample_data/Hurricanes.csv")

print(hurricanes_df.head())
print(hurricanes_df.describe())

plt.figure(figsize=(12, 6))
plt.bar(hurricanes_df['Year'], df['Hurricanes'])
plt.xlabel('Year')
plt.ylabel('Number of Hurricanes')
plt.title('Number of Hurricanes per Year')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
#    Year  Hurricanes
# 0  1914           0
# 1  1915           5
# 2  1916          10
# 3  1917           2
# 4  1918           4
#               Year  Hurricanes
# count   101.000000  101.000000
# mean   1964.000000    5.693069
# std      29.300171    2.667368
# min    1914.000000    0.000000
# 25%    1939.000000    4.000000
# 50%    1964.000000    5.000000
# 75%    1989.000000    7.000000
# max    2014.000000   15.000000

# %% [markdown]
# ## 2. The dataset given, records data of city temperatures over the years 2014 and 2015. Plot the histogram of the temperatures over this period for the cities of San Francisco and Moscow.

# %%
import pandas as pd
import matplotlib.pyplot as plt

city_temps_df = pd.read_csv("/content/sample_data/CityTemps.csv")

print(city_temps_df.head())
print(city_temps_df.describe())

plt.figure(figsize=(12, 6))
plt.hist(city_temps_df['San Francisco'], bins=20, alpha=0.5, label='San Francisco')
plt.hist(city_temps_df['Moscow'], bins=20, alpha=0.5, label='Moscow')
plt.xlabel('Temperature')
plt.ylabel('Frequency')
plt.title('Temperature Distribution for San Francisco and Moscow')
plt.legend()
# Out:
#    Year  Month  Moscow  Melbourne  San Francisco
# 0  2014      1    -8.6       22.0           12.8
# 1  2014      2    -1.9       21.5           12.7
# 2  2014      3     2.8       19.5           15.0
# 3  2014      4     7.0       15.8           15.7
# 4  2014      5    16.0       13.9           17.5
#               Year      Month     Moscow  Melbourne  San Francisco
# count    24.000000  24.000000  24.000000  24.000000      24.000000
# mean   2014.500000   6.500000   7.133333  15.525000      16.241667
# std       0.510754   3.526299   9.008965   4.352835       2.984586
# min    2014.000000   1.000000  -8.600000   8.900000      10.300000
# 25%    2014.000000   3.750000  -0.175000  11.900000      14.475000
# 50%    2014.500000   6.500000   5.250000  15.700000      15.700000
# 75%    2015.000000   9.250000  16.025000  19.050000      19.325000
# max    2015.000000  12.000000  21.100000  22.000000      20.400000

# %% [markdown]
# ## 3. Plot a piechart of the number of models released by every manufacturer, recorded in the data provided. Also mention the name of the manufacturerwith the largest releases.

# %%
import pandas as pd
import matplotlib.pyplot as plt

car_models_df = pd.read_csv("/content/sample_data/Cars2015.csv")

print(car_models_df.head())
print(car_models_df.describe())

manufacturer_counts = car_models_df['Make'].value_counts()

plt.figure(figsize=(14, 10)) # Increased figure size to give more space for labels and percentages
plt.pie(manufacturer_counts, labels=manufacturer_counts.index, autopct='%1.1f%%', startangle=120, rotatelabels=True,
        pctdistance=1.05) # Added textprops to rotate percentage values
plt.axis('equal')
plt.title('Distribution of Car Models by Manufacturer', pad=55)
plt.show()
# Out:
#          Make       Model       Type  LowPrice  HighPrice Drive  CityMPG  \
# 0   Chevrolet       Spark  Hatchback    12.270     25.560   FWD       30
# 1     Hyundai      Accent  Hatchback    14.745     17.495   FWD       28
# 2         Kia         Rio      Sedan    13.990     18.290   FWD       28
# 3  Mitsubishi      Mirage  Hatchback    12.995     15.395   FWD       37
# 4      Nissan  Versa Note  Hatchback    14.180     17.960   FWD       31
#
#    HwyMPG  FuelCap  Length  Width  Wheelbase  Height  UTurn  Weight  Acc030  \
# 0      39      9.0     145     63         94      61     34    2345     4.4
# 1      37     11.4     172     67        101      57     37    2550     3.7
# 2      36     11.3     172     68        101      57     37    2575     3.5
# 3      44      9.2     149     66         97      59     32    2085     4.4
# 4      40     10.9     164     67        102      61     37    2470     4.0
#
#    Acc060  QtrMile  PageNum   Size
# ...

# %% [markdown]
# ## 4. Create csv file from the data **BigMartSaleaData.csv** and read it in the pandass dataframe.
#
# ### **Phase 1: Reading data**
# ### **Phase 2: Describe the data**
# ### Describe the data on the unitprice.
# ### **Phase 3: Filter the data**
# ### Create a new  dataframe  having columns `name`,`net_price`,`date` and  group all the records according to name.
# ### **Phase 4: Plotting graph**
# ### Plot the graph after calculating total sales by each customer. Customer name should be the on the  x-axis and total sales on  y-axis. Refer to  sample-salesv2 to answer the following questions

# %%
## Data missing from the above question. So, not attempted

# %% [markdown]
# ## 5. Let the x-axis data points and y-axis data points are X = [1,2,3,4] y = [20, 21, 20.5, 20.8]
#
# ### 5.1: Draw a Simple plot
# ### 5.2: Configure the line and markers in a simple plot
# ### 5.3: configure the axes
# ### 5.4: Give the title of the graph and labels of the x-axis and y-axis
# ### 5.5: Give error bar if y_error = [0.12, 0.13, 0.2, 0.1]
# ### 5.6: define width, and height as figsize=(4,5) DPI and adjust plot dpi=100
# ### 5.7: Give a font size of 14
# ### 5.8: Draw a scatter graph of any 50 random values of the x and y-axis
# ### 5.9: Create a dataframe from the following data'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'], 'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'], 'female': [0, 1, 1, 0, 1],'age': [42, 52, 36, 24, 73], 'preTestScore': [4, 24, 31, 2, 3],'postTestScore': [25, 94, 57, 62, 70]
# ### Draw a Scatterplot of `preTestScore` and `postTestScore`, with the size of each point determined by age.
# ### 5.10: Draw a Scatterplot from the data in question 9 of `preTestScore` and `postTestScore` with the size = 300 and the color determined by sex.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# 5.1: Draw a Simple plot
X = [1, 2, 3, 4]
y = [20, 21, 20.5, 20.8]

plt.figure()
plt.plot(X, y)
plt.title('5.1: Simple Plot')
plt.show()

# 5.2: Configure the line and markers in a simple plot
plt.figure()
plt.plot(X, y, linestyle='--', marker='o', color='red')
plt.title('5.2: Configured Line and Markers')
plt.show()

# 5.3: configure the axes
plt.figure()
plt.plot(X, y)
plt.xlim(0, 5)
plt.ylim(19, 22)
plt.title('5.3: Configured Axes')
plt.show()

# 5.4: Give the title of the graph and labels of the x-axis and y-axis
plt.figure()
plt.plot(X, y)
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.title('5.4: Title and Labels')
plt.show()

# 5.5: Give error bar if y_error = [0.12, 0.13, 0.2, 0.1]
y_error = [0.12, 0.13, 0.2, 0.1]
plt.figure()
plt.errorbar(X, y, yerr=y_error, capsize=3)
plt.title('5.5: Plot with Error Bars')
plt.show()

# 5.6: define width, and height as figsize=(4,5) DPI and adjust plot dpi=100
plt.figure(figsize=(4, 5), dpi=100)
plt.plot(X, y)
plt.title('5.6: Configured Figure Size and DPI')
plt.show()

# 5.7: Give a font size of 14
plt.figure()
plt.plot(X, y)
plt.xlabel('X-axis Label', fontsize=14)
plt.ylabel('Y-axis Label', fontsize=14)
plt.title('5.7: Increased Font Size', fontsize=14)
plt.show()


# 5.8: Draw a scatter graph of any 50 random values of the x and y-axis
np.random.seed(42) # for reproducibility
random_x = np.random.rand(50) * 10
random_y = np.random.rand(50) * 10

plt.figure()
plt.scatter(random_x, random_y)
plt.xlabel('Random X')
plt.ylabel('Random Y')
plt.title('5.8: Scatter Plot of Random Values')
plt.show()

# 5.9: Create a dataframe and draw a Scatterplot of preTestScore and postTestScore, with the size of each point determined by age.
data = {'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
        'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'],
        'female': [0, 1, 1, 0, 1],
        'age': [42, 52, 36, 24, 73],
        'preTestScore': [4, 24, 31, 2, 3],
        'postTestScore': [25, 94, 57, 62, 70]}
df = pd.DataFrame(data)

plt.figure()
plt.scatter(df['preTestScore'], df['postTestScore'], s=df['age'])
plt.xlabel('Pre-Test Score')
plt.ylabel('Post-Test Score')
plt.title('5.9: Scatter Plot of Scores by Age')
plt.show()

# 5.10: Draw a Scatterplot from the data in question 9 of preTestScore and postTestScore with the size = 300 and the color determined by sex.
plt.figure()
plt.scatter(df['preTestScore'], df['postTestScore'], s=300, c=df['female'], cmap='viridis')
plt.xlabel('Pre-Test Score')
plt.ylabel('Post-Test Score')
plt.title('5.10: Scatter Plot of Scores by Sex')
plt.colorbar(label='Female (1) / Male (0)')
plt.show()

# %% [markdown]
# ## 6. Case Study
# ### **Domain** - Education
# ### **Focus** - Data analysis
# ###Business challenge/requirement
# You are a data analyst with the University of California. The University  has  data of Maths, Physics and Data Structure score of sophomore students. This data is stored in different files. The University has hired a data science company to do analysis of scores and find if there is any correlation ofscore with age, ethnicity,etc. Before the data is given to the company, you are required todo data wrangling.
#
# ### Key issues
# Ensure student identity is not revealed to the agency and only relevant data is shared.
#
# ### Considerations
# NONE
#
# ### Data volume
# Only around 1800 records are shared in files MathScoreTerm1.csv,DSScoreTerm1.csv,and PhysicsScoreTerm1.csv.
#
# ### Additional information
# NA
#
# ### Business benefits
#
# The University  can enrol  more  students by  improving  its  international ranking through a personalized course/curriculum for students
#
# ### Approach to Solve
#
# You have to use the fundamentals of NumPy and pandas covered in module 5 and 6.
# 1. Read the three CSVfiles,which contain the score of the same students in term1 for each Subject
# 2. Remove the name and ethnicity column (to ensure confidentiality)
# 3. Fill missing score data with zero
# 4. Merge the three files
# 5. Change Sex(M/F) Column to 1/2 for further analysis
# 6. Store the data in a new file - ScoreFinal.csv
#
# ### Enhancements for code
# You can try these enhancements in code
# 1. Convert ethnicity to a numerical value
# 2. Fill the missing score for a student to the average of the class

# %%
import pandas as pd
import numpy as np

# 1. Read the three CSV files
try:
    math_df = pd.read_csv('/content/sample_data/MathScoreTerm1.csv')
    ds_df = pd.read_csv('/content/sample_data/DSScoreTerm1.csv')
    physics_df = pd.read_csv('/content/sample_data/PhysicsScoreTerm1.csv')

    print("Successfully read all three CSV files.")

    # 2. Remove the name and ethnicity column
    math_df = math_df.drop(['Name', 'Ethinicity'], axis=1)
    ds_df = ds_df.drop(['Name', 'Ethinicity'], axis=1)
    physics_df = physics_df.drop(['Name', 'Ethinicity'], axis=1)

    print("Removed 'Name' and 'Ethinicity' columns from all dataframes.")

    # 3. Fill missing score data with zero
    math_df['Score'] = math_df['Score'].fillna(0)
    ds_df['Score'] = ds_df['Score'].fillna(0)
    physics_df['Score'] = physics_df['Score'].fillna(0)


    print("Filled missing score data with zero.")

    # 4. Merge the three files
    merged_df = pd.merge(math_df, ds_df, on='ID', suffixes=('_math', '_ds'))
    merged_df = pd.merge(merged_df, physics_df, on='ID', suffixes=('_merged', '_physics'))

    # Rename the score columns after merging to be more descriptive
    merged_df.rename(columns={'Score_math': 'Math_Score', 'Score_ds': 'DS_Score', 'Score': 'Physics_Score'}, inplace=True)


    print("Merged the three dataframes.")
    print(merged_df.head())

    # 5. Change Sex(M/F) Column to 1/2 for further analysis
    merged_df['Sex'] = merged_df['Sex'].map({'M': 1, 'F': 2})

    print("Changed 'Sex' column to numerical values (M=1, F=2).")
    print(merged_df.head())

    # 6. Store the data in a new file - ScoreFinal.csv
    merged_df.to_csv('ScoreFinal.csv', index=False)

    print("Saved the final processed data to ScoreFinal.csv")

except FileNotFoundError as e:
    print(f"Error: One of the CSV files not found: {e}")
except KeyError as e:
    print(f"Error: A required column was not found: {e}")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Successfully read all three CSV files.
# Removed 'Name' and 'Ethinicity' columns from all dataframes.
# Filled missing score data with zero.
# Merged the three dataframes.
#    Math Score  Age_math Subject_math Sex_math  ID  DS Score  Age_ds  \
# 0        88.0        18        Maths        M   1      82.0      18
# 1        85.0        19        Maths        M   2      79.0      19
# 2        45.0        19        Maths        M   3      39.0      19
# 3        82.0        18        Maths        M   4      76.0      18
# 4        82.0        18        Maths        F   5      76.0      18
#
#       Subject_ds Sex_ds  Physics Score  Age  Subject Sex
# 0  Data Structue      M           84.0   18  Physics   M
# 1  Data Structue      M           81.0   19  Physics   M
# 2  Data Structue      M           41.0   19  Physics   M
# 3  Data Structue      M           78.0   18  Physics   M
# 4  Data Structue      F           78.0   18  Physics   F
# ...
